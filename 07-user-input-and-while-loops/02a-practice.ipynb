# %% [markdown]
# # User Input and While Loops
#
# ## Practice
#
# When buying tickets to a movie, your age determines which movies you're allowed to see (G, PG, PG-13, R). Write a `while` loop that asks a user for their age, then prints the highest rated movie they are allowed to see. Include a quit prompt that will use `break` to stop the loop. Can you think of a reasonable use for the `continue` statement in this example?

# %%
while True:
    response = input("Enter your age, or q to quit: ")
    if response == 'q':
        break
    
    age = float(response)

    if age < 4:
        print('You should find an adult')
        continue

    if age < 8:
        print('You can watch G rated movies')
    elif age < 13: 
        print('You can watch PG rated movies')
    elif age < 18:
        print('You can watch PG-13 rated movies')
    elif age < 120:
        print('You can watch R rated movies')
    else:
        print('How?! What are your secrets?')
# Out:
# How?! What are your secrets?
# You should find an adult
# You should find an adult
# You can watch R rated movies
